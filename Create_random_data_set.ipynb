# %% [markdown]
# The np.random.normal function generates numbers based on the normal (Gaussian) distribution. The key characteristics of the normal distribution are the mean and the standard deviation:
#
# Mean (μ): The center of the distribution. In this case, it is 1.
# Standard Deviation (σ): The spread of the distribution. In this case, it is 5.
# The values generated by this function will be centered around the mean (1), with the spread determined by the standard deviation (5). The normal distribution has the following properties:
#
# About 68% of the values will fall within one standard deviation from the mean:
# 𝜇
# ±
# 𝜎
# μ±σ.
# About 95% of the values will fall within two standard deviations from the mean:
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ.
# About 99.7% of the values will fall within three standard deviations from the mean:
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ.
# So, for np.random.normal(1, 5, 10):
#
# Approximately 68% of the values will be between
# 1
# −
# 5
# 1−5 and
# 1
# +
# 5
# 1+5, which is between -4 and 6.
# Approximately 95% of the values will be between
# 1
# −
# 10
# 1−10 and
# 1
# +
# 10
# 1+10, which is between -9 and 11.
# Approximately 99.7% of the values will be between
# 1
# −
# 15
# 1−15 and
# 1
# +
# 15
# 1+15, which is between -14 and 16.
# When I mentioned -4 earlier, it was to illustrate the range within one standard deviation from the mean, which is
# 𝜇
# −
# 𝜎
# μ−σ to
# 𝜇
# +
# 𝜎
# μ+σ. In this case, that range is from -4 (1 - 5) to 6 (1 + 5). This is where about 68% of the generated values will fall.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Set the seed for reproducibility
np.random.seed(42)

# %%
# Generate random CGPA values between 2.0 and 4.0
cgpa = np.random.uniform(2.0, 4.0, 100)

# %%
# Assume a linear relationship: Package (LPA) = 1.5 * CGPA + noise
noise = np.random.normal(0, 0.5, cgpa.shape)
package = 1.5 * cgpa + noise

# %%
# Create a DataFrame
data = pd.DataFrame({
    'CGPA': cgpa,
    'Package (LPA)': package
})

# %%
data.head()
# Out:
#        CGPA  Package (LPA)
# 0  2.749080       4.167144
# 1  3.901429       5.702639
# 2  3.463988       5.241862
# 3  3.197317       3.802191
# 4  2.312037       3.358220

# %%
plt.scatter(data['CGPA'],data['Package (LPA)'])
plt.plot(x_train,lr.predict(x_train),color='red')

# %%
x=data.iloc[:,0:1]

# %%
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[2.749080]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.17568992])

# %%
b=lr.intercept_

# %%
m=lr.coef_

# %%
y= m*x + b

# %%
y= m * 2.749080 + b

# %%
y
# Out:
# array([4.17568992])
